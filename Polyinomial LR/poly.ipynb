# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X=6*np.random.rand(200,1)-3
y=0.8*X**2+0.9*X+np.random.randn(200,1)+2

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X,y)
plt.scatter(X,y)
plt.plot(X,lr.predict(X),c='red')

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2,include_bias=False)
X_trans=poly.fit_transform(X)
lr2=LinearRegression()
lr2.fit(X_trans,y)
plt.scatter(X,y)
X_new = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
X_new_trans = poly.transform(X_new)
y_new = lr2.predict(X_new_trans)
plt.plot(X_new,y_new,c='red')
print(lr.intercept_,lr2.coef_)
# Out:
# [4.65183527] [[0.93388952 0.77327717]]
